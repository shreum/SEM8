# %% [markdown]
# ```
# # This is formatted as code
# ```
# Recurrent neural network (RNN) Use the Google stock prices dataset and design a time series analysis and prediction system using RNN.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import datetime
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.metrics import r2_score

# %%
#data=pd.read_csv("/content/Google_Stock_Price_Train.csv",index_col='Date',parse_dates=True)
data=pd.read_csv("/content/Google_Stock_Price_Train.csv")
data
# Out:
#             Date    Open    High     Low   Close      Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1       1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2       1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3       1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4       1/9/2012  322.04  322.29  309.46  620.76  11,688,800
# ...          ...     ...     ...     ...     ...         ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91     623,400
# 1254  12/27/2016  790.68  797.86  787.66  791.55     789,100
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1,153,800
# 1256  12/29/2016  783.33  785.93  778.92  782.79     744,300
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 6 columns]

# %%
data['Close']=data['Close'].str.replace(',','').astype(float)
data['Volume']=data['Volume'].str.replace(',','').astype(float)

# %% [markdown]
# In the dataset, the Volume column had thousand seperated values, which is taken as string when usually loading to Pandas DataFrame. I have specified that ',' is used as the thousand separator when loading, so that the ',' will not be there when loading to our program. Then it'll be loaded as a numerical value.
#
# Plotting the Data

# %%
ax1 = data.plot(x="Date", y=["Open", "High", "Low", "Close"],  figsize=(18,10),title='Open, High, Low, Close Stock Prices of Google Stocks')
ax1.set_ylabel("Stock Price")

ax2 = data.plot(x="Date", y=["Volume"],  figsize=(18,9))
ax2.set_ylabel("Stock Volume")
# Out:
# Text(0, 0.5, 'Stock Volume')

# %% [markdown]
# When inspecting the first plot, we can see that in the closing value of stock prior to 2014/03/26, there is a significant gap between the closing price and the other prices, where as after this date, the closing price has also been closer to other prices.
#
# When inspecting the second plot, we can see that there are significant fluctuations in the Stock Volume over the time. And it is quite hard to find a trend/pattern in this the data in Stock Volume (the one we need to predict).
#
# Preprocessing Data
# Preprocessing data includes handling missing values and outliers, applying feature coding techniques if needed, scale & standardize features.
#
# Checking for Missing values

# %%
# Getting a summary of missing values for each field/attribute
print(data.isnull().sum())
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %% [markdown]
# We can see that there are no missing values in the dataset.
#
# Handling Outliers
#
# According to the above graph plots that indicate the Open, High, Low and Close values of the Stock prices, the Close price is as mentioned earlier, has a significant gap with the other values. The surprising fact is that, the Close value has even become higher than the High value (highest price of stock for a given day), which is not real.
#
# Ref: https://www.mit.edu/~mbarker/formula1/f1help/11-ch-10.htm
#
# Let us also check outliers for attributes by using box plots as follows.

# %%
data[['Open','High','Low','Close','Volume']].plot(kind= 'box' ,layout=(1,5),subplots=True, sharex=False, sharey=False, figsize=(20,6),color='blue')
plt.show()

# %% [markdown]
# We can see that there are outliers in the Close and Volume attributes. However, i will not remove any outliers here since there are only a limited number of datapoints (less than 1300) and if we remove outliers, the dataset will become even smaller.
#
# Feature Encoding
#
# When we check the 1st 10 records of the dataset, we could see that all the data in the dataset are numerical data, and there are no categorical data that needs encoding. Therefore, no feature encoding process was carried out on this dataset.
#
# Feature Scaling
#
# MinMaxScaler, which is said to be better to be used with time-series data, was used on this dataset for the feature scaling purposes.
#
# https://machinelearningmastery.com/normalize-standardize-time-series-data-python/
#
# The following set of graphs show the attribute histogram before scaling

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>],
#        [<Axes: title={'center': 'Low'}>,
#         <Axes: title={'center': 'Close'}>],
#        [<Axes: title={'center': 'Volume'}>, <Axes: >]], dtype=object)

# %%
data
# Out:
#             Date    Open    High     Low   Close      Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7380500.0
# 1       1/4/2012  331.27  333.87  329.08  666.45   5749400.0
# 2       1/5/2012  329.83  330.75  326.89  657.21   6590300.0
# 3       1/6/2012  328.34  328.77  323.68  648.24   5405900.0
# 4       1/9/2012  322.04  322.29  309.46  620.76  11688800.0
# ...          ...     ...     ...     ...     ...         ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91    623400.0
# 1254  12/27/2016  790.68  797.86  787.66  791.55    789100.0
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1153800.0
# 1256  12/29/2016  783.33  785.93  778.92  782.79    744300.0
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1770000.0
#
# [1258 rows x 6 columns]

# %%
scaler = MinMaxScaler()
data_without_date = data[['Open','High','Low','Close','Volume']]
data_scaled = pd.DataFrame(scaler.fit_transform(data_without_date))

# %%
data_scaled
# Out:
#              0         1         2         3         4
# 0     0.085814  0.096401  0.090449  0.237573  0.295258
# 1     0.097012  0.098344  0.098235  0.241514  0.229936
# 2     0.094334  0.092517  0.094086  0.228781  0.263612
# 3     0.091562  0.088819  0.088006  0.216419  0.216179
# 4     0.079842  0.076718  0.061070  0.178548  0.467797
# ...        ...       ...       ...       ...       ...
# 1253  0.952043  0.955292  0.966169  0.411656  0.024650
# 1254  0.951633  0.964853  0.966889  0.413916  0.031286
# 1255  0.957251  0.958074  0.958441  0.404958  0.045891
# 1256  0.937960  0.942574  0.950333  0.401844  0.029491
# 1257  0.936881  0.936691  0.934214  0.386726  0.070569
#
# [1258 rows x 5 columns]

# %%
     

data_scaled.hist()
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: title={'center': '3'}>],
#        [<Axes: title={'center': '4'}>, <Axes: >]], dtype=object)

# %% [markdown]
# Feature Engineering
# Drawing the Correlation Matrix Correlation Coefficient checking mechanism checks the relationship between the different features with the predicting attribute.

# %%
plt.figure(figsize=(6,6))
sns.heatmap(data.corr())
# Out:
# <ipython-input-12-373595b0d5cd>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <Axes: >

# %% [markdown]
# We can see from the correlation matrix that the features Open, High, and Low, all are highly correlated with each other. Therefore, it is sufficient to consider only one feature from the above 3 features and remove the rest.
#
# Furthermore, I am removing the Close field since it contains many abnormal data values, which is like a contexual outlier.

# %%
data_scaled=data_scaled.drop([1,2,4], axis=1)
data_scaled
# Out:
#              0         3
# 0     0.085814  0.237573
# 1     0.097012  0.241514
# 2     0.094334  0.228781
# 3     0.091562  0.216419
# 4     0.079842  0.178548
# ...        ...       ...
# 1253  0.952043  0.411656
# 1254  0.951633  0.413916
# 1255  0.957251  0.404958
# 1256  0.937960  0.401844
# 1257  0.936881  0.386726
#
# [1258 rows x 2 columns]

# %% [markdown]
# Developing the RNN Model
#
# When developing an RNN Model, we have to reshape the data that we are feeding into the model. To do that, first we have to find a pattern in the data available and define the number of timesteps according to the pattern.
#
# When considering the plots we have created for this we could not see a clear cut pattern/trend in the data by just visual inspection. Therefore, I have taken the following code snippet to split the data into a sequence by trying to identify any pattern available.
#
# Since there are two features in our dataset after cleaning, I have used a split sequence method for a multivariate dataset.

# %%
def split_seq_multivariate(sequence, n_past, n_future):
    
    '''
    n_past ==> no of past observations
    n_future ==> no of future observations 
    '''
    x, y = [], [] 
    for window_start in range(len(sequence)):
        past_end = window_start + n_past
        future_end = past_end + n_future
        if future_end > len(sequence):
            break
        # slicing the past and future parts of the window
        past   = sequence[window_start:past_end, :]
        future = sequence[past_end:future_end, -1]
        x.append(past)
        y.append(future)
    
    return np.array(x), np.array(y)

# %% [markdown]
# In RNN, since we are dealing with time series data, we have to specify how many past data points we will be considering when generating the sequence.
#
# In here, i have taken 60 past data points (time steps) when generating the data sequences.

# %%
# specify the window size
n_steps = 60

data_scaled = data_scaled.to_numpy()
data_scaled.shape
# Out:
# (1258, 2)

# %% [markdown]
# Next, I am using the split_seq_multivariate function to split the dataset into sequences.

# %%
# split into samples
X, y = split_seq_multivariate(data_scaled, n_steps,1)

# %%
X[1].shape
# Out:
# (60, 2)

# %%
y
# Out:
# array([[0.21420007],
#        [0.20434657],
#        [0.21216047],
#        ...,
#        [0.40495845],
#        [0.40184391],
#        [0.38672602]])

# %%
# X is in the shape of [samples, timesteps, features]
print(X.shape)
print(y.shape)

# make y to the shape of [samples]
y=y[:,0]
y.shape
# Out:
# (1198, 60, 2)
# (1198, 1)
# (1198,)

# %% [markdown]
# Splitting the Data
#
# In this step, I will be splitting the sequenced data into train and test sections with 0.2 test size.
#
# Furthermore, i have split the training set again to train and validation data. I have not used the test data to do the validation because validation data are used to fine tune the model, and if i used the testing data for validation purposes, then those data will be already seen by the model when trying to predict them later.
#
# Ref: https://machinelearningmastery.com/difference-test-validation-datasets/

# %%
# split into train/test
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=50)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (958, 60, 2) (240, 60, 2) (958,) (240,)

# %%
# further dividing the training set into train and validation data
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.2,random_state=30)

print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
# Out:
# (766, 60, 2) (192, 60, 2) (766,) (192,)

# %% [markdown]
# Next I am defining the model using Tensorflow Keras LSTM and Dense layers.
#
# In the LSTM layer, i have not specified the activation function explicitly because in the Keras Documentation it is specified that the default activation function for LSTM is tanh and default recurrent activation function is sigmoid. Therefore those default acivation functions will be used here.
#
# Ref: https://www.tensorflow.org/api_docs/python/tf/keras/layers/LSTMCell
#
# Define Model

# %%
# define RNN model
model = Sequential()
model.add(LSTM(612, input_shape=(n_steps,2)))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(1))

# %% [markdown]
# The following code line gives a summary of the model we have created, mentioning each layers information.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 612)               1505520
#
#  dense (Dense)               (None, 50)                30650
#
#  dense_1 (Dense)             (None, 50)                2550
#
#  dense_2 (Dense)             (None, 30)                1530
#
#  dense_3 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 1,540,281
# Trainable params: 1,540,281
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Compiling and Training the Model
#
# Next we will be compiling and fitting the model with the training data, and using the validation data to fine tune our model.

# %%
# compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
# fit the model
history = model.fit(X_train, y_train, epochs=250, batch_size=32, verbose=2, validation_data=(X_val, y_val))  # has used mini batch learning, with batch_s
# Out:
# Epoch 1/250
# 24/24 - 13s - loss: 0.0382 - mae: 0.1368 - val_loss: 0.0158 - val_mae: 0.0940 - 13s/epoch - 551ms/step
# Epoch 2/250
# 24/24 - 0s - loss: 0.0056 - mae: 0.0490 - val_loss: 0.0043 - val_mae: 0.0323 - 319ms/epoch - 13ms/step
# Epoch 3/250
# 24/24 - 0s - loss: 0.0027 - mae: 0.0277 - val_loss: 0.0036 - val_mae: 0.0287 - 353ms/epoch - 15ms/step
# Epoch 4/250
# 24/24 - 0s - loss: 0.0026 - mae: 0.0271 - val_loss: 0.0057 - val_mae: 0.0473 - 319ms/epoch - 13ms/step
# Epoch 5/250
# 24/24 - 0s - loss: 0.0027 - mae: 0.0283 - val_loss: 0.0033 - val_mae: 0.0270 - 316ms/epoch - 13ms/step
# Epoch 6/250
# 24/24 - 0s - loss: 0.0018 - mae: 0.0208 - val_loss: 0.0028 - val_mae: 0.0278 - 328ms/epoch - 14ms/step
# Epoch 7/250
# 24/24 - 0s - loss: 0.0023 - mae: 0.0258 - val_loss: 0.0032 - val_mae: 0.0227 - 323ms/epoch - 13ms/step
# Epoch 8/250
# 24/24 - 0s - loss: 0.0021 - mae: 0.0223 - val_loss: 0.0031 - val_mae: 0.0226 - 352ms/epoch - 15ms/step
# Epoch 9/250
# 24/24 - 0s - loss: 0.0021 - mae: 0.0240 - val_loss: 0.0028 - val_mae: 0.0243 - 360ms/epoch - 15ms/step
# Epoch 10/250
# 24/24 - 0s - loss: 0.0021 - mae: 0.0264 - val_loss: 0.0031 - val_mae: 0.0346 - 327ms/epoch - 14ms/step
# Epoch 11/250
# 24/24 - 0s - loss: 0.0020 - mae: 0.0238 - val_loss: 0.0025 - val_mae: 0.0245 - 318ms/epoch - 13ms/step
# Epoch 12/250
# 24/24 - 0s - loss: 0.0017 - mae: 0.0217 - val_loss: 0.0026 - val_mae: 0.0245 - 318ms/epoch - 13ms/step
# Epoch 13/250
# 24/24 - 0s - loss: 0.0018 - mae: 0.0239 - val_loss: 0.0030 - val_mae: 0.0303 - 350ms/epoch - 15ms/step
# Epoch 14/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0188 - val_loss: 0.0023 - val_mae: 0.0271 - 356ms/epoch - 15ms/step
# Epoch 15/250
# 24/24 - 0s - loss: 0.0019 - mae: 0.0254 - val_loss: 0.0019 - val_mae: 0.0229 - 359ms/epoch - 15ms/step
# Epoch 16/250
# 24/24 - 0s - loss: 0.0016 - mae: 0.0212 - val_loss: 0.0019 - val_mae: 0.0211 - 390ms/epoch - 16ms/step
# Epoch 17/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0175 - val_loss: 0.0014 - val_mae: 0.0204 - 387ms/epoch - 16ms/step
# Epoch 18/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0212 - val_loss: 0.0016 - val_mae: 0.0221 - 363ms/epoch - 15ms/step
# Epoch 19/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0186 - val_loss: 0.0016 - val_mae: 0.0185 - 347ms/epoch - 14ms/step
# Epoch 20/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0181 - val_loss: 0.0014 - val_mae: 0.0183 - 322ms/epoch - 13ms/step
# Epoch 21/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0175 - val_loss: 0.0015 - val_mae: 0.0217 - 321ms/epoch - 13ms/step
# Epoch 22/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0177 - val_loss: 0.0013 - val_mae: 0.0184 - 317ms/epoch - 13ms/step
# Epoch 23/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0178 - val_loss: 0.0017 - val_mae: 0.0253 - 329ms/epoch - 14ms/step
# Epoch 24/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0213 - val_loss: 0.0014 - val_mae: 0.0185 - 350ms/epoch - 15ms/step
# Epoch 25/250
# 24/24 - 0s - loss: 0.0016 - mae: 0.0218 - val_loss: 0.0013 - val_mae: 0.0180 - 321ms/epoch - 13ms/step
# Epoch 26/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0177 - val_loss: 0.0018 - val_mae: 0.0281 - 324ms/epoch - 14ms/step
# Epoch 27/250
# 24/24 - 0s - loss: 0.0016 - mae: 0.0215 - val_loss: 0.0014 - val_mae: 0.0192 - 325ms/epoch - 14ms/step
# Epoch 28/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0206 - val_loss: 0.0016 - val_mae: 0.0214 - 321ms/epoch - 13ms/step
# Epoch 29/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0146 - val_loss: 0.0013 - val_mae: 0.0199 - 322ms/epoch - 13ms/step
# Epoch 30/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0205 - val_loss: 0.0012 - val_mae: 0.0166 - 355ms/epoch - 15ms/step
# Epoch 31/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0148 - val_loss: 0.0012 - val_mae: 0.0191 - 317ms/epoch - 13ms/step
# Epoch 32/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0176 - val_loss: 0.0012 - val_mae: 0.0171 - 353ms/epoch - 15ms/step
# Epoch 33/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0155 - val_loss: 0.0011 - val_mae: 0.0185 - 360ms/epoch - 15ms/step
# Epoch 34/250
# 24/24 - 0s - loss: 0.0016 - mae: 0.0210 - val_loss: 0.0012 - val_mae: 0.0189 - 322ms/epoch - 13ms/step
# Epoch 35/250
# 24/24 - 0s - loss: 0.0019 - mae: 0.0249 - val_loss: 0.0014 - val_mae: 0.0216 - 320ms/epoch - 13ms/step
# Epoch 36/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0172 - val_loss: 0.0011 - val_mae: 0.0171 - 318ms/epoch - 13ms/step
# Epoch 37/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0199 - val_loss: 0.0011 - val_mae: 0.0167 - 349ms/epoch - 15ms/step
# Epoch 38/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0138 - val_loss: 0.0011 - val_mae: 0.0184 - 336ms/epoch - 14ms/step
# Epoch 39/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0166 - val_loss: 0.0011 - val_mae: 0.0209 - 321ms/epoch - 13ms/step
# Epoch 40/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0188 - val_loss: 0.0016 - val_mae: 0.0296 - 316ms/epoch - 13ms/step
# Epoch 41/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0175 - val_loss: 9.4096e-04 - val_mae: 0.0164 - 355ms/epoch - 15ms/step
# Epoch 42/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0150 - val_loss: 0.0011 - val_mae: 0.0217 - 350ms/epoch - 15ms/step
# Epoch 43/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0199 - val_loss: 0.0014 - val_mae: 0.0212 - 354ms/epoch - 15ms/step
# Epoch 44/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0146 - val_loss: 0.0012 - val_mae: 0.0203 - 354ms/epoch - 15ms/step
# Epoch 45/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0192 - val_loss: 8.4327e-04 - val_mae: 0.0175 - 349ms/epoch - 15ms/step
# Epoch 46/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0178 - val_loss: 8.1268e-04 - val_mae: 0.0185 - 316ms/epoch - 13ms/step
# Epoch 47/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0165 - val_loss: 8.0103e-04 - val_mae: 0.0152 - 360ms/epoch - 15ms/step
# Epoch 48/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0167 - val_loss: 6.7037e-04 - val_mae: 0.0147 - 328ms/epoch - 14ms/step
# Epoch 49/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0157 - val_loss: 8.5890e-04 - val_mae: 0.0201 - 383ms/epoch - 16ms/step
# Epoch 50/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0157 - val_loss: 7.8346e-04 - val_mae: 0.0184 - 358ms/epoch - 15ms/step
# Epoch 51/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0173 - val_loss: 9.4784e-04 - val_mae: 0.0214 - 364ms/epoch - 15ms/step
# Epoch 52/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0179 - val_loss: 8.2020e-04 - val_mae: 0.0198 - 363ms/epoch - 15ms/step
# Epoch 53/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0186 - val_loss: 7.8053e-04 - val_mae: 0.0170 - 384ms/epoch - 16ms/step
# Epoch 54/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0156 - val_loss: 7.8492e-04 - val_mae: 0.0201 - 360ms/epoch - 15ms/step
# Epoch 55/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0160 - val_loss: 5.1172e-04 - val_mae: 0.0140 - 377ms/epoch - 16ms/step
# Epoch 56/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0166 - val_loss: 4.8396e-04 - val_mae: 0.0134 - 319ms/epoch - 13ms/step
# Epoch 57/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0190 - val_loss: 4.7571e-04 - val_mae: 0.0133 - 317ms/epoch - 13ms/step
# Epoch 58/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0181 - val_loss: 5.0449e-04 - val_mae: 0.0149 - 320ms/epoch - 13ms/step
# Epoch 59/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0198 - val_loss: 4.8557e-04 - val_mae: 0.0138 - 329ms/epoch - 14ms/step
# Epoch 60/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0164 - val_loss: 8.5572e-04 - val_mae: 0.0208 - 319ms/epoch - 13ms/step
# Epoch 61/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0171 - val_loss: 4.5888e-04 - val_mae: 0.0137 - 356ms/epoch - 15ms/step
# Epoch 62/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0146 - val_loss: 7.8030e-04 - val_mae: 0.0212 - 326ms/epoch - 14ms/step
# Epoch 63/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0144 - val_loss: 6.6367e-04 - val_mae: 0.0172 - 319ms/epoch - 13ms/step
# Epoch 64/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0216 - val_loss: 5.0516e-04 - val_mae: 0.0155 - 352ms/epoch - 15ms/step
# Epoch 65/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0172 - val_loss: 4.3578e-04 - val_mae: 0.0132 - 320ms/epoch - 13ms/step
# Epoch 66/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0163 - val_loss: 4.2943e-04 - val_mae: 0.0129 - 352ms/epoch - 15ms/step
# Epoch 67/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0152 - val_loss: 0.0011 - val_mae: 0.0250 - 364ms/epoch - 15ms/step
# Epoch 68/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0174 - val_loss: 4.4941e-04 - val_mae: 0.0140 - 350ms/epoch - 15ms/step
# Epoch 69/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0185 - val_loss: 4.4441e-04 - val_mae: 0.0138 - 318ms/epoch - 13ms/step
# Epoch 70/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0146 - val_loss: 3.9121e-04 - val_mae: 0.0143 - 349ms/epoch - 15ms/step
# Epoch 71/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0149 - val_loss: 8.8104e-04 - val_mae: 0.0225 - 319ms/epoch - 13ms/step
# Epoch 72/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0212 - val_loss: 6.2017e-04 - val_mae: 0.0190 - 318ms/epoch - 13ms/step
# Epoch 73/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0160 - val_loss: 4.6782e-04 - val_mae: 0.0154 - 324ms/epoch - 14ms/step
# Epoch 74/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0164 - val_loss: 0.0011 - val_mae: 0.0276 - 349ms/epoch - 15ms/step
# Epoch 75/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0186 - val_loss: 0.0016 - val_mae: 0.0361 - 323ms/epoch - 13ms/step
# Epoch 76/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0189 - val_loss: 8.1860e-04 - val_mae: 0.0237 - 349ms/epoch - 15ms/step
# Epoch 77/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0185 - val_loss: 0.0011 - val_mae: 0.0282 - 318ms/epoch - 13ms/step
# Epoch 78/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0181 - val_loss: 5.6097e-04 - val_mae: 0.0181 - 319ms/epoch - 13ms/step
# Epoch 79/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0163 - val_loss: 6.8088e-04 - val_mae: 0.0206 - 348ms/epoch - 14ms/step
# Epoch 80/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0173 - val_loss: 3.1089e-04 - val_mae: 0.0129 - 349ms/epoch - 15ms/step
# Epoch 81/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0142 - val_loss: 5.2807e-04 - val_mae: 0.0165 - 327ms/epoch - 14ms/step
# Epoch 82/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0155 - val_loss: 3.7856e-04 - val_mae: 0.0150 - 318ms/epoch - 13ms/step
# Epoch 83/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0154 - val_loss: 6.1699e-04 - val_mae: 0.0208 - 320ms/epoch - 13ms/step
# Epoch 84/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0138 - val_loss: 4.9968e-04 - val_mae: 0.0163 - 351ms/epoch - 15ms/step
# Epoch 85/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0212 - val_loss: 7.0131e-04 - val_mae: 0.0228 - 351ms/epoch - 15ms/step
# Epoch 86/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0160 - val_loss: 3.2849e-04 - val_mae: 0.0138 - 360ms/epoch - 15ms/step
# Epoch 87/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0138 - val_loss: 3.6601e-04 - val_mae: 0.0138 - 362ms/epoch - 15ms/step
# Epoch 88/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0177 - val_loss: 3.8093e-04 - val_mae: 0.0155 - 388ms/epoch - 16ms/step
# Epoch 89/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0146 - val_loss: 3.1447e-04 - val_mae: 0.0130 - 394ms/epoch - 16ms/step
# Epoch 90/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0185 - val_loss: 3.0971e-04 - val_mae: 0.0136 - 383ms/epoch - 16ms/step
# Epoch 91/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0134 - val_loss: 7.4835e-04 - val_mae: 0.0207 - 325ms/epoch - 14ms/step
# Epoch 92/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0183 - val_loss: 3.1430e-04 - val_mae: 0.0130 - 356ms/epoch - 15ms/step
# Epoch 93/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0138 - val_loss: 7.8544e-04 - val_mae: 0.0212 - 352ms/epoch - 15ms/step
# Epoch 94/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0178 - val_loss: 5.0879e-04 - val_mae: 0.0162 - 354ms/epoch - 15ms/step
# Epoch 95/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0200 - val_loss: 3.4999e-04 - val_mae: 0.0136 - 348ms/epoch - 14ms/step
# Epoch 96/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0136 - val_loss: 2.7277e-04 - val_mae: 0.0124 - 319ms/epoch - 13ms/step
# Epoch 97/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0138 - val_loss: 4.0891e-04 - val_mae: 0.0163 - 326ms/epoch - 14ms/step
# Epoch 98/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0186 - val_loss: 2.8316e-04 - val_mae: 0.0128 - 348ms/epoch - 14ms/step
# Epoch 99/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0164 - val_loss: 3.5958e-04 - val_mae: 0.0146 - 351ms/epoch - 15ms/step
# Epoch 100/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0158 - val_loss: 2.3264e-04 - val_mae: 0.0115 - 318ms/epoch - 13ms/step
# Epoch 101/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0164 - val_loss: 4.9535e-04 - val_mae: 0.0185 - 358ms/epoch - 15ms/step
# Epoch 102/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0171 - val_loss: 3.5388e-04 - val_mae: 0.0151 - 346ms/epoch - 14ms/step
# Epoch 103/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0158 - val_loss: 8.2096e-04 - val_mae: 0.0249 - 355ms/epoch - 15ms/step
# Epoch 104/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0158 - val_loss: 7.8435e-04 - val_mae: 0.0245 - 320ms/epoch - 13ms/step
# Epoch 105/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0166 - val_loss: 2.9649e-04 - val_mae: 0.0129 - 317ms/epoch - 13ms/step
# Epoch 106/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0167 - val_loss: 6.4106e-04 - val_mae: 0.0206 - 322ms/epoch - 13ms/step
# Epoch 107/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0149 - val_loss: 2.8237e-04 - val_mae: 0.0121 - 356ms/epoch - 15ms/step
# Epoch 108/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0168 - val_loss: 2.2414e-04 - val_mae: 0.0112 - 316ms/epoch - 13ms/step
# Epoch 109/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0145 - val_loss: 3.9069e-04 - val_mae: 0.0155 - 317ms/epoch - 13ms/step
# Epoch 110/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0162 - val_loss: 6.4697e-04 - val_mae: 0.0217 - 319ms/epoch - 13ms/step
# Epoch 111/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0144 - val_loss: 2.7962e-04 - val_mae: 0.0121 - 354ms/epoch - 15ms/step
# Epoch 112/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0160 - val_loss: 2.9036e-04 - val_mae: 0.0126 - 347ms/epoch - 14ms/step
# Epoch 113/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0128 - val_loss: 7.5995e-04 - val_mae: 0.0208 - 318ms/epoch - 13ms/step
# Epoch 114/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0163 - val_loss: 2.9727e-04 - val_mae: 0.0131 - 323ms/epoch - 13ms/step
# Epoch 115/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0148 - val_loss: 2.8828e-04 - val_mae: 0.0132 - 353ms/epoch - 15ms/step
# Epoch 116/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0157 - val_loss: 2.5778e-04 - val_mae: 0.0122 - 322ms/epoch - 13ms/step
# Epoch 117/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0179 - val_loss: 6.9039e-04 - val_mae: 0.0209 - 322ms/epoch - 13ms/step
# Epoch 118/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0210 - val_loss: 2.4442e-04 - val_mae: 0.0116 - 319ms/epoch - 13ms/step
# Epoch 119/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0170 - val_loss: 2.6465e-04 - val_mae: 0.0126 - 324ms/epoch - 13ms/step
# Epoch 120/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0183 - val_loss: 3.9939e-04 - val_mae: 0.0163 - 390ms/epoch - 16ms/step
# Epoch 121/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0189 - val_loss: 3.4012e-04 - val_mae: 0.0137 - 385ms/epoch - 16ms/step
# Epoch 122/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0176 - val_loss: 4.4784e-04 - val_mae: 0.0165 - 364ms/epoch - 15ms/step
# Epoch 123/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0134 - val_loss: 2.6059e-04 - val_mae: 0.0116 - 357ms/epoch - 15ms/step
# Epoch 124/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0133 - val_loss: 3.7246e-04 - val_mae: 0.0139 - 392ms/epoch - 16ms/step
# Epoch 125/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0140 - val_loss: 4.2627e-04 - val_mae: 0.0171 - 340ms/epoch - 14ms/step
# Epoch 126/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0161 - val_loss: 3.5493e-04 - val_mae: 0.0147 - 320ms/epoch - 13ms/step
# Epoch 127/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0202 - val_loss: 2.2787e-04 - val_mae: 0.0112 - 358ms/epoch - 15ms/step
# Epoch 128/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0136 - val_loss: 5.3583e-04 - val_mae: 0.0166 - 351ms/epoch - 15ms/step
# Epoch 129/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0157 - val_loss: 4.3120e-04 - val_mae: 0.0172 - 324ms/epoch - 14ms/step
# Epoch 130/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0140 - val_loss: 2.7836e-04 - val_mae: 0.0125 - 324ms/epoch - 14ms/step
# Epoch 131/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0159 - val_loss: 2.8454e-04 - val_mae: 0.0124 - 326ms/epoch - 14ms/step
# Epoch 132/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0154 - val_loss: 2.4326e-04 - val_mae: 0.0113 - 348ms/epoch - 15ms/step
# Epoch 133/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0132 - val_loss: 2.4435e-04 - val_mae: 0.0113 - 318ms/epoch - 13ms/step
# Epoch 134/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0120 - val_loss: 5.1229e-04 - val_mae: 0.0156 - 320ms/epoch - 13ms/step
# Epoch 135/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0172 - val_loss: 3.7537e-04 - val_mae: 0.0148 - 350ms/epoch - 15ms/step
# Epoch 136/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0130 - val_loss: 6.9643e-04 - val_mae: 0.0197 - 322ms/epoch - 13ms/step
# Epoch 137/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0147 - val_loss: 5.8229e-04 - val_mae: 0.0186 - 318ms/epoch - 13ms/step
# Epoch 138/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0172 - val_loss: 2.5621e-04 - val_mae: 0.0111 - 360ms/epoch - 15ms/step
# Epoch 139/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0143 - val_loss: 2.7281e-04 - val_mae: 0.0119 - 354ms/epoch - 15ms/step
# Epoch 140/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0147 - val_loss: 3.0827e-04 - val_mae: 0.0134 - 324ms/epoch - 13ms/step
# Epoch 141/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0163 - val_loss: 3.2922e-04 - val_mae: 0.0128 - 353ms/epoch - 15ms/step
# Epoch 142/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0142 - val_loss: 5.6951e-04 - val_mae: 0.0196 - 324ms/epoch - 14ms/step
# Epoch 143/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0179 - val_loss: 2.8491e-04 - val_mae: 0.0122 - 324ms/epoch - 13ms/step
# Epoch 144/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0115 - val_loss: 5.5257e-04 - val_mae: 0.0167 - 355ms/epoch - 15ms/step
# Epoch 145/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0148 - val_loss: 5.5330e-04 - val_mae: 0.0188 - 354ms/epoch - 15ms/step
# Epoch 146/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0163 - val_loss: 2.8502e-04 - val_mae: 0.0112 - 319ms/epoch - 13ms/step
# Epoch 147/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0154 - val_loss: 3.6337e-04 - val_mae: 0.0143 - 363ms/epoch - 15ms/step
# Epoch 148/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0150 - val_loss: 3.2601e-04 - val_mae: 0.0130 - 325ms/epoch - 14ms/step
# Epoch 149/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0173 - val_loss: 3.1640e-04 - val_mae: 0.0119 - 317ms/epoch - 13ms/step
# Epoch 150/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0143 - val_loss: 4.9874e-04 - val_mae: 0.0182 - 328ms/epoch - 14ms/step
# Epoch 151/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0135 - val_loss: 3.6018e-04 - val_mae: 0.0130 - 323ms/epoch - 13ms/step
# Epoch 152/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0159 - val_loss: 3.1633e-04 - val_mae: 0.0124 - 319ms/epoch - 13ms/step
# Epoch 153/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0126 - val_loss: 6.3952e-04 - val_mae: 0.0185 - 326ms/epoch - 14ms/step
# Epoch 154/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0183 - val_loss: 4.5964e-04 - val_mae: 0.0160 - 352ms/epoch - 15ms/step
# Epoch 155/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0158 - val_loss: 4.0961e-04 - val_mae: 0.0153 - 398ms/epoch - 17ms/step
# Epoch 156/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0173 - val_loss: 3.8428e-04 - val_mae: 0.0138 - 363ms/epoch - 15ms/step
# Epoch 157/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0148 - val_loss: 4.4683e-04 - val_mae: 0.0154 - 364ms/epoch - 15ms/step
# Epoch 158/250
# 24/24 - 1s - loss: 0.0010 - mae: 0.0126 - val_loss: 3.4949e-04 - val_mae: 0.0126 - 598ms/epoch - 25ms/step
# Epoch 159/250
# 24/24 - 1s - loss: 0.0013 - mae: 0.0200 - val_loss: 4.3053e-04 - val_mae: 0.0157 - 668ms/epoch - 28ms/step
# Epoch 160/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0137 - val_loss: 7.2033e-04 - val_mae: 0.0198 - 352ms/epoch - 15ms/step
# Epoch 161/250
# 24/24 - 1s - loss: 0.0012 - mae: 0.0186 - val_loss: 3.9986e-04 - val_mae: 0.0142 - 510ms/epoch - 21ms/step
# Epoch 162/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0143 - val_loss: 4.4753e-04 - val_mae: 0.0157 - 394ms/epoch - 16ms/step
# Epoch 163/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0146 - val_loss: 3.8018e-04 - val_mae: 0.0141 - 324ms/epoch - 13ms/step
# Epoch 164/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0172 - val_loss: 3.0381e-04 - val_mae: 0.0117 - 318ms/epoch - 13ms/step
# Epoch 165/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0152 - val_loss: 4.9069e-04 - val_mae: 0.0166 - 316ms/epoch - 13ms/step
# Epoch 166/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0130 - val_loss: 4.1728e-04 - val_mae: 0.0151 - 357ms/epoch - 15ms/step
# Epoch 167/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0160 - val_loss: 3.3565e-04 - val_mae: 0.0126 - 364ms/epoch - 15ms/step
# Epoch 168/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0152 - val_loss: 4.5006e-04 - val_mae: 0.0163 - 348ms/epoch - 15ms/step
# Epoch 169/250
# 24/24 - 0s - loss: 0.0016 - mae: 0.0197 - val_loss: 4.9962e-04 - val_mae: 0.0155 - 324ms/epoch - 13ms/step
# Epoch 170/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0172 - val_loss: 3.5167e-04 - val_mae: 0.0130 - 318ms/epoch - 13ms/step
# Epoch 171/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0158 - val_loss: 7.9710e-04 - val_mae: 0.0233 - 352ms/epoch - 15ms/step
# Epoch 172/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0160 - val_loss: 4.3338e-04 - val_mae: 0.0147 - 327ms/epoch - 14ms/step
# Epoch 173/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0184 - val_loss: 3.9610e-04 - val_mae: 0.0148 - 317ms/epoch - 13ms/step
# Epoch 174/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0137 - val_loss: 4.6637e-04 - val_mae: 0.0176 - 322ms/epoch - 13ms/step
# Epoch 175/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0176 - val_loss: 4.2595e-04 - val_mae: 0.0163 - 355ms/epoch - 15ms/step
# Epoch 176/250
# 24/24 - 0s - loss: 0.0015 - mae: 0.0212 - val_loss: 6.4161e-04 - val_mae: 0.0208 - 317ms/epoch - 13ms/step
# Epoch 177/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0172 - val_loss: 5.5874e-04 - val_mae: 0.0182 - 321ms/epoch - 13ms/step
# Epoch 178/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0154 - val_loss: 5.6260e-04 - val_mae: 0.0183 - 326ms/epoch - 14ms/step
# Epoch 179/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0179 - val_loss: 3.8117e-04 - val_mae: 0.0139 - 327ms/epoch - 14ms/step
# Epoch 180/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0147 - val_loss: 7.0911e-04 - val_mae: 0.0228 - 320ms/epoch - 13ms/step
# Epoch 181/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0160 - val_loss: 5.0099e-04 - val_mae: 0.0180 - 357ms/epoch - 15ms/step
# Epoch 182/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0164 - val_loss: 4.6694e-04 - val_mae: 0.0151 - 320ms/epoch - 13ms/step
# Epoch 183/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0167 - val_loss: 3.5738e-04 - val_mae: 0.0145 - 319ms/epoch - 13ms/step
# Epoch 184/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0132 - val_loss: 4.1472e-04 - val_mae: 0.0158 - 358ms/epoch - 15ms/step
# Epoch 185/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0148 - val_loss: 3.1499e-04 - val_mae: 0.0127 - 322ms/epoch - 13ms/step
# Epoch 186/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0127 - val_loss: 4.1350e-04 - val_mae: 0.0139 - 356ms/epoch - 15ms/step
# Epoch 187/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0163 - val_loss: 2.8817e-04 - val_mae: 0.0123 - 330ms/epoch - 14ms/step
# Epoch 188/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0128 - val_loss: 3.7818e-04 - val_mae: 0.0147 - 338ms/epoch - 14ms/step
# Epoch 189/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0152 - val_loss: 2.9914e-04 - val_mae: 0.0121 - 390ms/epoch - 16ms/step
# Epoch 190/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0147 - val_loss: 3.8889e-04 - val_mae: 0.0154 - 365ms/epoch - 15ms/step
# Epoch 191/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0129 - val_loss: 3.6713e-04 - val_mae: 0.0139 - 388ms/epoch - 16ms/step
# Epoch 192/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0149 - val_loss: 6.1723e-04 - val_mae: 0.0204 - 387ms/epoch - 16ms/step
# Epoch 193/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0155 - val_loss: 5.9785e-04 - val_mae: 0.0202 - 385ms/epoch - 16ms/step
# Epoch 194/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0160 - val_loss: 3.0388e-04 - val_mae: 0.0122 - 367ms/epoch - 15ms/step
# Epoch 195/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0156 - val_loss: 3.7617e-04 - val_mae: 0.0138 - 354ms/epoch - 15ms/step
# Epoch 196/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0136 - val_loss: 4.0260e-04 - val_mae: 0.0154 - 353ms/epoch - 15ms/step
# Epoch 197/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0131 - val_loss: 3.3526e-04 - val_mae: 0.0125 - 327ms/epoch - 14ms/step
# Epoch 198/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0128 - val_loss: 4.1959e-04 - val_mae: 0.0144 - 332ms/epoch - 14ms/step
# Epoch 199/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0159 - val_loss: 4.6382e-04 - val_mae: 0.0165 - 353ms/epoch - 15ms/step
# Epoch 200/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0139 - val_loss: 5.3452e-04 - val_mae: 0.0184 - 350ms/epoch - 15ms/step
# Epoch 201/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0183 - val_loss: 8.4729e-04 - val_mae: 0.0248 - 323ms/epoch - 13ms/step
# Epoch 202/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0166 - val_loss: 5.5132e-04 - val_mae: 0.0174 - 355ms/epoch - 15ms/step
# Epoch 203/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0153 - val_loss: 3.0631e-04 - val_mae: 0.0126 - 325ms/epoch - 14ms/step
# Epoch 204/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0159 - val_loss: 3.3237e-04 - val_mae: 0.0137 - 326ms/epoch - 14ms/step
# Epoch 205/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0143 - val_loss: 4.3003e-04 - val_mae: 0.0137 - 326ms/epoch - 14ms/step
# Epoch 206/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0133 - val_loss: 3.1201e-04 - val_mae: 0.0123 - 331ms/epoch - 14ms/step
# Epoch 207/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0141 - val_loss: 8.4707e-04 - val_mae: 0.0254 - 359ms/epoch - 15ms/step
# Epoch 208/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0153 - val_loss: 3.0997e-04 - val_mae: 0.0123 - 360ms/epoch - 15ms/step
# Epoch 209/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0168 - val_loss: 7.4759e-04 - val_mae: 0.0218 - 361ms/epoch - 15ms/step
# Epoch 210/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0139 - val_loss: 3.1003e-04 - val_mae: 0.0123 - 337ms/epoch - 14ms/step
# Epoch 211/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0138 - val_loss: 3.5360e-04 - val_mae: 0.0138 - 322ms/epoch - 13ms/step
# Epoch 212/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0134 - val_loss: 4.8326e-04 - val_mae: 0.0147 - 325ms/epoch - 14ms/step
# Epoch 213/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0151 - val_loss: 4.0114e-04 - val_mae: 0.0152 - 323ms/epoch - 13ms/step
# Epoch 214/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0140 - val_loss: 3.2674e-04 - val_mae: 0.0132 - 354ms/epoch - 15ms/step
# Epoch 215/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0119 - val_loss: 5.0702e-04 - val_mae: 0.0171 - 357ms/epoch - 15ms/step
# Epoch 216/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0147 - val_loss: 5.5218e-04 - val_mae: 0.0186 - 357ms/epoch - 15ms/step
# Epoch 217/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0141 - val_loss: 4.1420e-04 - val_mae: 0.0150 - 329ms/epoch - 14ms/step
# Epoch 218/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0160 - val_loss: 3.7756e-04 - val_mae: 0.0139 - 349ms/epoch - 15ms/step
# Epoch 219/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0127 - val_loss: 4.3137e-04 - val_mae: 0.0149 - 326ms/epoch - 14ms/step
# Epoch 220/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0175 - val_loss: 3.8313e-04 - val_mae: 0.0150 - 327ms/epoch - 14ms/step
# Epoch 221/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0126 - val_loss: 6.6812e-04 - val_mae: 0.0187 - 330ms/epoch - 14ms/step
# Epoch 222/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0163 - val_loss: 3.3544e-04 - val_mae: 0.0122 - 325ms/epoch - 14ms/step
# Epoch 223/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0138 - val_loss: 7.9001e-04 - val_mae: 0.0201 - 365ms/epoch - 15ms/step
# Epoch 224/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0215 - val_loss: 3.9508e-04 - val_mae: 0.0147 - 375ms/epoch - 16ms/step
# Epoch 225/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0139 - val_loss: 3.4533e-04 - val_mae: 0.0129 - 408ms/epoch - 17ms/step
# Epoch 226/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0151 - val_loss: 4.2505e-04 - val_mae: 0.0150 - 355ms/epoch - 15ms/step
# Epoch 227/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0162 - val_loss: 5.3849e-04 - val_mae: 0.0179 - 380ms/epoch - 16ms/step
# Epoch 228/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0142 - val_loss: 5.6154e-04 - val_mae: 0.0191 - 381ms/epoch - 16ms/step
# Epoch 229/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0145 - val_loss: 3.7109e-04 - val_mae: 0.0136 - 338ms/epoch - 14ms/step
# Epoch 230/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0146 - val_loss: 2.9922e-04 - val_mae: 0.0119 - 357ms/epoch - 15ms/step
# Epoch 231/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0140 - val_loss: 4.1019e-04 - val_mae: 0.0147 - 326ms/epoch - 14ms/step
# Epoch 232/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0149 - val_loss: 3.3865e-04 - val_mae: 0.0137 - 321ms/epoch - 13ms/step
# Epoch 233/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0148 - val_loss: 9.9995e-04 - val_mae: 0.0267 - 321ms/epoch - 13ms/step
# Epoch 234/250
# 24/24 - 0s - loss: 0.0014 - mae: 0.0188 - val_loss: 3.1460e-04 - val_mae: 0.0120 - 326ms/epoch - 14ms/step
# Epoch 235/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0150 - val_loss: 6.6559e-04 - val_mae: 0.0207 - 360ms/epoch - 15ms/step
# Epoch 236/250
# 24/24 - 0s - loss: 0.0013 - mae: 0.0183 - val_loss: 3.6539e-04 - val_mae: 0.0127 - 359ms/epoch - 15ms/step
# Epoch 237/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0150 - val_loss: 4.3310e-04 - val_mae: 0.0144 - 358ms/epoch - 15ms/step
# Epoch 238/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0145 - val_loss: 5.1781e-04 - val_mae: 0.0181 - 352ms/epoch - 15ms/step
# Epoch 239/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0172 - val_loss: 5.1193e-04 - val_mae: 0.0162 - 359ms/epoch - 15ms/step
# Epoch 240/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0139 - val_loss: 3.5312e-04 - val_mae: 0.0127 - 364ms/epoch - 15ms/step
# Epoch 241/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0148 - val_loss: 4.2024e-04 - val_mae: 0.0143 - 353ms/epoch - 15ms/step
# Epoch 242/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0144 - val_loss: 4.9495e-04 - val_mae: 0.0148 - 323ms/epoch - 13ms/step
# Epoch 243/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0185 - val_loss: 3.5594e-04 - val_mae: 0.0129 - 360ms/epoch - 15ms/step
# Epoch 244/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0154 - val_loss: 3.4384e-04 - val_mae: 0.0127 - 320ms/epoch - 13ms/step
# Epoch 245/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0133 - val_loss: 4.1987e-04 - val_mae: 0.0134 - 353ms/epoch - 15ms/step
# Epoch 246/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0164 - val_loss: 4.1496e-04 - val_mae: 0.0140 - 355ms/epoch - 15ms/step
# Epoch 247/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0158 - val_loss: 9.0826e-04 - val_mae: 0.0261 - 322ms/epoch - 13ms/step
# Epoch 248/250
# 24/24 - 0s - loss: 0.0012 - mae: 0.0153 - val_loss: 3.4691e-04 - val_mae: 0.0134 - 328ms/epoch - 14ms/step
# Epoch 249/250
# 24/24 - 0s - loss: 0.0011 - mae: 0.0140 - val_loss: 4.0597e-04 - val_mae: 0.0139 - 326ms/epoch - 14ms/step
# Epoch 250/250
# 24/24 - 0s - loss: 0.0010 - mae: 0.0129 - val_loss: 6.4133e-04 - val_mae: 0.0197 - 330ms/epoch - 14ms/step

# %%
from matplotlib import pyplot
# plot learning curves
pyplot.title('Learning Curves')
pyplot.xlabel('Epoch')
pyplot.ylabel('Root Mean Squared Error')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='val')
pyplot.legend()
pyplot.show()

# %% [markdown]
# Model Evaluation and Predictions
#
# Next, i will be using the model.evaluate() and model.predict() methods.
#
# The model.evaluate() is used to only check the MSE, RMSE, MAE values of our model when the testing data is used. This does not provide us with the results the model would predict. Therefore to see the results that the model would predict, i have used the model.predict() function. Later I have plotted the actual and predicted values of the test data to see how well our model has performed.
#
# Ref: https://stackoverflow.com/questions/44476706/what-is-the-difference-between-keras-model-evaluate-and-model-predict

# %%
# evaluate the model
mse, mae = model.evaluate(X_test, y_test, verbose=0)
print('MSE: %.3f, RMSE: %.3f, MAE: %.3f' % (mse, np.sqrt(mse), mae))
# Out:
# MSE: 0.000, RMSE: 0.022, MAE: 0.018

# %%
# predicting y_test values
print(X_test.shape)
predicted_values = model.predict(X_test)
print(predicted_values.shape)
# print(predicted_values)
# Out:
# (240, 60, 2)
# 8/8 [==============================] - 0s 5ms/step
# (240, 1)

# %%
plt.plot(y_test,c = 'r')
plt.plot(predicted_values,c = 'y')
plt.xlabel('Day')
plt.ylabel('Stock Price Volume')
plt.title('Stock Price Volume Prediction Graph using RNN (LSTM)')
plt.legend(['Actual','Predicted'],loc = 'lower right')
plt.figure(figsize=(10,6))

# %% [markdown]
# Using R Squared
#
# The R squared is a metric we can use to evaluate how well our regression based (model that handle continuous data) have performed.
#
# R squared can vary between 0 and 1 and we can evaluate our model using this metric, while a negative value would mean that the training has not been done properly.

# %%
# evaluating using R squared
R_square = r2_score(y_test, predicted_values) 
 
print(R_square)
# Out:
# 0.9928113313877398
